# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import igraph as ig
import random
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')

# %%
# read csv

# steam_200K
df = pd.read_csv("../Untitled Folder/steam_200k.csv", names=['UserID', 'Game', 'Action', 'Hours', 'Other'])

# all_games
df1 = pd.read_csv("../Untitled Folder/all_games.csv",encoding='utf-8')
df1.columns = ['Name', 'Platform', 'Year', 'summary', 'meta_score', 'user_review']
df1 = df1.drop(['summary'], axis = 1)
all_games_data = df1.query("Year>2005")

# vssales_year
df2 = pd.read_csv("../Untitled Folder/vgsales_year.csv",encoding='utf-8')
df2 = df2.drop(['Rank'], axis = 1)
vgsales_year_data = df2.query("Year>2005")
vgsales_year_data = df2.drop(['Year'], axis = 1)

#Video_Games_as_at_22_Dec_2016
df3 = pd.read_csv("../Untitled Folder/Video_Games_Sales_as_at_22_Dec_2016.csv",encoding='utf-8')
Video_Games_Sales_as_at_22_Dec_2016_data = df3.query("Year_of_Release>2005")

# %%
merge_data1 = pd.merge(all_games_data, vgsales_year_data, on=['Name', 'Platform'], how='left')
merge_data1.fillna(0)
# Out:
#                                              Name Platform  Year meta_score  \
# 0                             Grand Theft Auto IV      PS3  2008         98
# 1                             Grand Theft Auto IV     X360  2008         98
# 2                              Super Mario Galaxy      Wii  2007         97
# 3                            Super Mario Galaxy 2      Wii  2010         97
# 4                           Red Dead Redemption 2     XOne  2018         97
# ...                                           ...      ...   ...        ...
# 14565                       Rambo: The Video Game      PS3  2014         23
# 14566                    Fast & Furious: Showdown     X360  2013         22
# 14567  Afro Samurai 2: Revenge of Kuma Volume One      PS4  2015         21
# 14568   Infestation: Survivor Stories (The War Z)       PC  2012         20
# 14569         Leisure Suit Larry: Box Office Bust       PC  2009         20
#
#       user_review     Genre             Publisher  NA_Sales  EU_Sales  \
# 0             7.7    Action  Take-Two Interactive      4.76      3.76
# 1             7.9    Action  Take-Two Interactive      6.76      3.10
# 2             9.1  Platform              Nintendo      6.16      3.40
# 3             9.1  Platform              Nintendo      3.66      2.42
# 4               8         0                     0      0.00      0.00
# ...           ...       ...                   ...       ...       ...
# 14565         1.8         0                     0      0.00      0.00
# 14566         1.3    Action            Activision      0.00      0.04
# 14567         2.9         0                     0      0.00      0.00
# 14568         1.7         0                     0      0.00      0.00
# 14569           2         0                     0      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          0.44         1.62         10.57
# 1          0.14         1.03         11.02
# 2          1.20         0.76         11.52
# 3          0.98         0.64          7.69
# 4          0.00         0.00          0.00
# ...         ...          ...           ...
# 14565      0.00         0.00          0.00
# 14566      0.00         0.00          0.05
# 14567      0.00         0.00          0.00
# 14568      0.00         0.00          0.00
# 14569      0.00         0.00          0.00
#
# [14570 rows x 12 columns]

# %%
# all_games_data shows the year by genre until the most recent.
# all_games_data can count the largest amount of games.

plt.figure(figsize = (15,5))
plt.title('Count Games', fontsize=15)
plt.xlabel('Year', fontsize=13)
plt.grid(color ='lightgray')
plt.plot(all_games_data.groupby(['Year']).count(), color = 'black')

plt.savefig(f'./Count_Games.png')

# %%
temp = merge_data1.drop(['Name'],axis =1)
temp = temp.drop(['Platform'],axis =1)
temp = temp.drop(['meta_score'],axis =1)
temp = temp.drop(['user_review'],axis =1)
plt.figure(figsize = (15,5))
plt.title('Count Games', fontsize=15)
plt.xlabel('Year', fontsize=13)
plt.grid(color ='lightgray')
plt.plot(temp.groupby(['Year']).count(), color = 'black')
print(temp.groupby(['Year']).count())
# Out:
#       Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year
# 2006    451        451       451       451       451          451
# 2007    515        515       515       515       515          515
# 2008    507        507       507       507       507          507
# 2009    487        487       487       487       487          487
# 2010    395        395       395       395       395          395
# 2011    361        361       361       361       361          361
# 2012    259        259       259       259       259          259
# 2013    205        205       205       205       205          205
# 2014    196        196       196       196       196          196
# 2015    186        186       186       186       186          186
# 2016    115        115       115       115       115          115
# 2017     14         14        14        14        14           14
# 2018      0          0         0         0         0            0
# 2019      0          0         0         0         0            0
# 2020      1          1         1         1         1            1
# 2021      0          0         0         0         0            0
#
#       Global_Sales
# Year
# 2006           451
# 2007           515
# 2008           507
# 2009           487
# 2010           395
# 2011           361
# 2012           259
# 2013           205
# 2014           196
# 2015           186
# 2016           115
# 2017            14
# 2018             0
# 2019             0
# 2020             1
# 2021             0
