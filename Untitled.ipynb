# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import igraph as ig
import random
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')

# %%
# read csv

# steam_200K
df = pd.read_csv("../Untitled Folder/steam_200k.csv", names=['UserID', 'Game', 'Action', 'Hours', 'Other'])

# all_games
df1 = pd.read_csv("../Untitled Folder/all_games.csv",encoding='utf-8')
df1.columns = ['Name', 'Platform', 'Year', 'summary', 'meta_score', 'user_review']
df1 = df1.drop(['summary'], axis = 1)
all_games_data = df1.query("Year>=2000")

# vssales_year
df2 = pd.read_csv("../Untitled Folder/vgsales_year.csv",encoding='utf-8')
df2 = df2.drop(['Rank'], axis = 1)
vgsales_year_data = df2.query("Year>=2000")
vgsales_year_data = df2.drop(['Year'], axis = 1)

#Video_Games_as_at_22_Dec_2016
df3 = pd.read_csv("../Untitled Folder/Video_Games_Sales_as_at_22_Dec_2016.csv",encoding='utf-8')
Video_Games_Sales_as_at_22_Dec_2016_data = df3.query("Year_of_Release>=2000")

# %%
merge_data1 = pd.merge(all_games_data, vgsales_year_data, on=['Name', 'Platform'], how='left')
merge_data1.fillna(0)
merge_data1
# Out:
#                                              Name Platform  Year meta_score  \
# 0                        Tony Hawk's Pro Skater 2       PS  2000         98
# 1                             Grand Theft Auto IV      PS3  2008         98
# 2                             Grand Theft Auto IV     X360  2008         98
# 3                              Super Mario Galaxy      Wii  2007         97
# 4                            Super Mario Galaxy 2      Wii  2010         97
# ...                                           ...      ...   ...        ...
# 18619                    Fast & Furious: Showdown     X360  2013         22
# 18620                     Drake of the 99 Dragons       XB  2003         22
# 18621  Afro Samurai 2: Revenge of Kuma Volume One      PS4  2015         21
# 18622   Infestation: Survivor Stories (The War Z)       PC  2012         20
# 18623         Leisure Suit Larry: Box Office Bust       PC  2009         20
#
#       user_review     Genre             Publisher  NA_Sales  EU_Sales  \
# 0             7.4    Sports            Activision      3.05      1.41
# 1             7.7    Action  Take-Two Interactive      4.76      3.76
# 2             7.9    Action  Take-Two Interactive      6.76      3.10
# 3             9.1  Platform              Nintendo      6.16      3.40
# 4             9.1  Platform              Nintendo      3.66      2.42
# ...           ...       ...                   ...       ...       ...
# 18619         1.3    Action            Activision      0.00      0.04
# 18620         1.7       NaN                   NaN       NaN       NaN
# 18621         2.9       NaN                   NaN       NaN       NaN
# 18622         1.7       NaN                   NaN       NaN       NaN
# 18623           2       NaN                   NaN       NaN       NaN
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          0.02         0.20          4.68
# 1          0.44         1.62         10.57
# 2          0.14         1.03         11.02
# 3          1.20         0.76         11.52
# 4          0.98         0.64          7.69
# ...         ...          ...           ...
# 18619      0.00         0.00          0.05
# 18620       NaN          NaN           NaN
# 18621       NaN          NaN           NaN
# 18622       NaN          NaN           NaN
# 18623       NaN          NaN           NaN
#
# [18624 rows x 12 columns]

# %%
temp = merge_data1.drop(['Publisher'], axis = 1)
grouptemp = temp.groupby(['Platform'])
grouptemp.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 3>()
#       1 temp = merge_data1.drop(['Publisher'], axis = 1)
#       2 grouptemp = temp.groupby(['Platform'])
# ----> 3 grouptemp.info()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'info'
